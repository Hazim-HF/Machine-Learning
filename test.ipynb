# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Tip:</b> Use blue boxes (alert-info) for tips and notes.
# If it’s a note, you don’t have to include the word “Note”.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Example:</b> Use yellow boxes for examples that are not
# inside code cells, or use for mathematical formulas if needed.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Up to you:</b> Use green boxes sparingly, and only for some specific
# purpose that the other boxes can't cover. For example, if you have a lot
# of related content to link to, maybe you decide to use green boxes for
# related links from each section of a notebook.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Just don't:</b> In general, avoid the red boxes. These should only be
# used for actions that might cause data loss or another major issue.
# </div>

# %% [markdown]
# %%HTML
# <style> code {background-color : lightgrey !important;} </style>

# %% [markdown]
# `highlight code`

# %% [markdown]
# ***
# horizontal lines
# ***

# %% [markdown]
# >indent

# %% [markdown]
# <span style="background-color: yellow;">py -m pip install numpy</span>

# %% [markdown]
# <pre><code>py -m pip install numpy</code></pre>

# %% [markdown]
# <span style="background-color: #fff9c4;">py -m pip install numpy</span>

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\user\\Documents\\Machine-Learning'

# %%
import pandas as pd
import itertools
hitters_df = pd.read_csv('data/hitters.csv')
hitters_df_clean = hitters_df.dropna().drop('Unnamed: 0', axis=1)
X_ = hitters_df_clean.drop(['Salary', 'League', 'Division', 'NewLeague'], axis=1).astype('float64')
dummies = pd.get_dummies(hitters_df_clean[['League', 'Division', 'NewLeague']])
X = pd.concat([X_, dummies[['League_N', 'Division_W', 'NewLeague_N']]], axis=1)
j=0
for combo in itertools.combinations(X.columns, 3):
    print(combo)
    j += 1
print(j)
# Out:
# ('AtBat', 'Hits', 'HmRun')
# ('AtBat', 'Hits', 'Runs')
# ('AtBat', 'Hits', 'RBI')
# ('AtBat', 'Hits', 'Walks')
# ('AtBat', 'Hits', 'Years')
# ('AtBat', 'Hits', 'CAtBat')
# ('AtBat', 'Hits', 'CHits')
# ('AtBat', 'Hits', 'CHmRun')
# ('AtBat', 'Hits', 'CRuns')
# ('AtBat', 'Hits', 'CRBI')
# ('AtBat', 'Hits', 'CWalks')
# ('AtBat', 'Hits', 'PutOuts')
# ('AtBat', 'Hits', 'Assists')
# ('AtBat', 'Hits', 'Errors')
# ('AtBat', 'Hits', 'League_N')
# ('AtBat', 'Hits', 'Division_W')
# ('AtBat', 'Hits', 'NewLeague_N')
# ('AtBat', 'HmRun', 'Runs')
# ('AtBat', 'HmRun', 'RBI')
# ('AtBat', 'HmRun', 'Walks')
# ('AtBat', 'HmRun', 'Years')
# ('AtBat', 'HmRun', 'CAtBat')
# ('AtBat', 'HmRun', 'CHits')
# ('AtBat', 'HmRun', 'CHmRun')
# ('AtBat', 'HmRun', 'CRuns')
# ('AtBat', 'HmRun', 'CRBI')
# ('AtBat', 'HmRun', 'CWalks')
# ('AtBat', 'HmRun', 'PutOuts')
# ('AtBat', 'HmRun', 'Assists')
# ('AtBat', 'HmRun', 'Errors')
# ('AtBat', 'HmRun', 'League_N')
# ('AtBat', 'HmRun', 'Division_W')
# ('AtBat', 'HmRun', 'NewLeague_N')
# ('AtBat', 'Runs', 'RBI')
# ('AtBat', 'Runs', 'Walks')
# ('AtBat', 'Runs', 'Years')
# ('AtBat', 'Runs', 'CAtBat')
# ('AtBat', 'Runs', 'CHits')
# ('AtBat', 'Runs', 'CHmRun')
# ('AtBat', 'Runs', 'CRuns')
# ('AtBat', 'Runs', 'CRBI')
# ('AtBat', 'Runs', 'CWalks')
# ('AtBat', 'Runs', 'PutOuts')
# ('AtBat', 'Runs', 'Assists')
# ('AtBat', 'Runs', 'Errors')
# ('AtBat', 'Runs', 'League_N')
# ('AtBat', 'Runs', 'Division_W')
# ('AtBat', 'Runs', 'NewLeague_N')
# ('AtBat', 'RBI', 'Walks')
# ('AtBat', 'RBI', 'Years')
# ('AtBat', 'RBI', 'CAtBat')
# ('AtBat', 'RBI', 'CHits')
# ('AtBat', 'RBI', 'CHmRun')
# ('AtBat', 'RBI', 'CRuns')
# ('AtBat', 'RBI', 'CRBI')
# ('AtBat', 'RBI', 'CWalks')
# ('AtBat', 'RBI', 'PutOuts')
# ('AtBat', 'RBI', 'Assists')
# ('AtBat', 'RBI', 'Errors')
# ('AtBat', 'RBI', 'League_N')
# ('AtBat', 'RBI', 'Division_W')
# ('AtBat', 'RBI', 'NewLeague_N')
# ('AtBat', 'Walks', 'Years')
# ('AtBat', 'Walks', 'CAtBat')
# ('AtBat', 'Walks', 'CHits')
# ('AtBat', 'Walks', 'CHmRun')
# ('AtBat', 'Walks', 'CRuns')
# ('AtBat', 'Walks', 'CRBI')
# ('AtBat', 'Walks', 'CWalks')
# ('AtBat', 'Walks', 'PutOuts')
# ('AtBat', 'Walks', 'Assists')
# ('AtBat', 'Walks', 'Errors')
# ('AtBat', 'Walks', 'League_N')
# ('AtBat', 'Walks', 'Division_W')
# ('AtBat', 'Walks', 'NewLeague_N')
# ('AtBat', 'Years', 'CAtBat')
# ('AtBat', 'Years', 'CHits')
# ('AtBat', 'Years', 'CHmRun')
# ('AtBat', 'Years', 'CRuns')
# ('AtBat', 'Years', 'CRBI')
# ('AtBat', 'Years', 'CWalks')
# ('AtBat', 'Years', 'PutOuts')
# ('AtBat', 'Years', 'Assists')
# ('AtBat', 'Years', 'Errors')
# ('AtBat', 'Years', 'League_N')
# ('AtBat', 'Years', 'Division_W')
# ('AtBat', 'Years', 'NewLeague_N')
# ('AtBat', 'CAtBat', 'CHits')
# ('AtBat', 'CAtBat', 'CHmRun')
# ('AtBat', 'CAtBat', 'CRuns')
# ('AtBat', 'CAtBat', 'CRBI')
# ('AtBat', 'CAtBat', 'CWalks')
# ('AtBat', 'CAtBat', 'PutOuts')
# ('AtBat', 'CAtBat', 'Assists')
# ('AtBat', 'CAtBat', 'Errors')
# ('AtBat', 'CAtBat', 'League_N')
# ('AtBat', 'CAtBat', 'Division_W')
# ('AtBat', 'CAtBat', 'NewLeague_N')
# ('AtBat', 'CHits', 'CHmRun')
# ('AtBat', 'CHits', 'CRuns')
# ('AtBat', 'CHits', 'CRBI')
# ('AtBat', 'CHits', 'CWalks')
# ('AtBat', 'CHits', 'PutOuts')
# ('AtBat', 'CHits', 'Assists')
# ('AtBat', 'CHits', 'Errors')
# ('AtBat', 'CHits', 'League_N')
# ('AtBat', 'CHits', 'Division_W')
# ('AtBat', 'CHits', 'NewLeague_N')
# ('AtBat', 'CHmRun', 'CRuns')
# ('AtBat', 'CHmRun', 'CRBI')
# ('AtBat', 'CHmRun', 'CWalks')
# ('AtBat', 'CHmRun', 'PutOuts')
# ('AtBat', 'CHmRun', 'Assists')
# ('AtBat', 'CHmRun', 'Errors')
# ('AtBat', 'CHmRun', 'League_N')
# ('AtBat', 'CHmRun', 'Division_W')
# ('AtBat', 'CHmRun', 'NewLeague_N')
# ('AtBat', 'CRuns', 'CRBI')
# ('AtBat', 'CRuns', 'CWalks')
# ('AtBat', 'CRuns', 'PutOuts')
# ('AtBat', 'CRuns', 'Assists')
# ('AtBat', 'CRuns', 'Errors')
# ('AtBat', 'CRuns', 'League_N')
# ('AtBat', 'CRuns', 'Division_W')
# ('AtBat', 'CRuns', 'NewLeague_N')
# ('AtBat', 'CRBI', 'CWalks')
# ('AtBat', 'CRBI', 'PutOuts')
# ('AtBat', 'CRBI', 'Assists')
# ('AtBat', 'CRBI', 'Errors')
# ('AtBat', 'CRBI', 'League_N')
# ('AtBat', 'CRBI', 'Division_W')
# ('AtBat', 'CRBI', 'NewLeague_N')
# ('AtBat', 'CWalks', 'PutOuts')
# ('AtBat', 'CWalks', 'Assists')
# ('AtBat', 'CWalks', 'Errors')
# ('AtBat', 'CWalks', 'League_N')
# ('AtBat', 'CWalks', 'Division_W')
# ('AtBat', 'CWalks', 'NewLeague_N')
# ('AtBat', 'PutOuts', 'Assists')
# ('AtBat', 'PutOuts', 'Errors')
# ('AtBat', 'PutOuts', 'League_N')
# ('AtBat', 'PutOuts', 'Division_W')
# ('AtBat', 'PutOuts', 'NewLeague_N')
# ('AtBat', 'Assists', 'Errors')
# ('AtBat', 'Assists', 'League_N')
# ('AtBat', 'Assists', 'Division_W')
# ('AtBat', 'Assists', 'NewLeague_N')
# ('AtBat', 'Errors', 'League_N')
# ('AtBat', 'Errors', 'Division_W')
# ('AtBat', 'Errors', 'NewLeague_N')
# ('AtBat', 'League_N', 'Division_W')
# ('AtBat', 'League_N', 'NewLeague_N')
# ('AtBat', 'Division_W', 'NewLeague_N')
# ('Hits', 'HmRun', 'Runs')
# ('Hits', 'HmRun', 'RBI')
# ('Hits', 'HmRun', 'Walks')
# ('Hits', 'HmRun', 'Years')
# ('Hits', 'HmRun', 'CAtBat')
# ('Hits', 'HmRun', 'CHits')
# ('Hits', 'HmRun', 'CHmRun')
# ('Hits', 'HmRun', 'CRuns')
# ('Hits', 'HmRun', 'CRBI')
# ('Hits', 'HmRun', 'CWalks')
# ('Hits', 'HmRun', 'PutOuts')
# ('Hits', 'HmRun', 'Assists')
# ('Hits', 'HmRun', 'Errors')
# ('Hits', 'HmRun', 'League_N')
# ('Hits', 'HmRun', 'Division_W')
# ('Hits', 'HmRun', 'NewLeague_N')
# ('Hits', 'Runs', 'RBI')
# ('Hits', 'Runs', 'Walks')
# ('Hits', 'Runs', 'Years')
# ('Hits', 'Runs', 'CAtBat')
# ('Hits', 'Runs', 'CHits')
# ('Hits', 'Runs', 'CHmRun')
# ('Hits', 'Runs', 'CRuns')
# ('Hits', 'Runs', 'CRBI')
# ('Hits', 'Runs', 'CWalks')
# ('Hits', 'Runs', 'PutOuts')
# ('Hits', 'Runs', 'Assists')
# ('Hits', 'Runs', 'Errors')
# ('Hits', 'Runs', 'League_N')
# ('Hits', 'Runs', 'Division_W')
# ('Hits', 'Runs', 'NewLeague_N')
# ('Hits', 'RBI', 'Walks')
# ('Hits', 'RBI', 'Years')
# ('Hits', 'RBI', 'CAtBat')
# ('Hits', 'RBI', 'CHits')
# ('Hits', 'RBI', 'CHmRun')
# ('Hits', 'RBI', 'CRuns')
# ('Hits', 'RBI', 'CRBI')
# ('Hits', 'RBI', 'CWalks')
# ('Hits', 'RBI', 'PutOuts')
# ('Hits', 'RBI', 'Assists')
# ('Hits', 'RBI', 'Errors')
# ('Hits', 'RBI', 'League_N')
# ('Hits', 'RBI', 'Division_W')
# ('Hits', 'RBI', 'NewLeague_N')
# ('Hits', 'Walks', 'Years')
# ('Hits', 'Walks', 'CAtBat')
# ('Hits', 'Walks', 'CHits')
# ('Hits', 'Walks', 'CHmRun')
# ('Hits', 'Walks', 'CRuns')
# ('Hits', 'Walks', 'CRBI')
# ('Hits', 'Walks', 'CWalks')
# ('Hits', 'Walks', 'PutOuts')
# ('Hits', 'Walks', 'Assists')
# ('Hits', 'Walks', 'Errors')
# ('Hits', 'Walks', 'League_N')
# ('Hits', 'Walks', 'Division_W')
# ('Hits', 'Walks', 'NewLeague_N')
# ('Hits', 'Years', 'CAtBat')
# ('Hits', 'Years', 'CHits')
# ('Hits', 'Years', 'CHmRun')
# ('Hits', 'Years', 'CRuns')
# ('Hits', 'Years', 'CRBI')
# ('Hits', 'Years', 'CWalks')
# ('Hits', 'Years', 'PutOuts')
# ('Hits', 'Years', 'Assists')
# ('Hits', 'Years', 'Errors')
# ('Hits', 'Years', 'League_N')
# ('Hits', 'Years', 'Division_W')
# ('Hits', 'Years', 'NewLeague_N')
# ('Hits', 'CAtBat', 'CHits')
# ('Hits', 'CAtBat', 'CHmRun')
# ('Hits', 'CAtBat', 'CRuns')
# ('Hits', 'CAtBat', 'CRBI')
# ('Hits', 'CAtBat', 'CWalks')
# ('Hits', 'CAtBat', 'PutOuts')
# ('Hits', 'CAtBat', 'Assists')
# ('Hits', 'CAtBat', 'Errors')
# ('Hits', 'CAtBat', 'League_N')
# ('Hits', 'CAtBat', 'Division_W')
# ('Hits', 'CAtBat', 'NewLeague_N')
# ('Hits', 'CHits', 'CHmRun')
# ('Hits', 'CHits', 'CRuns')
# ('Hits', 'CHits', 'CRBI')
# ('Hits', 'CHits', 'CWalks')
# ('Hits', 'CHits', 'PutOuts')
# ('Hits', 'CHits', 'Assists')
# ('Hits', 'CHits', 'Errors')
# ('Hits', 'CHits', 'League_N')
# ('Hits', 'CHits', 'Division_W')
# ('Hits', 'CHits', 'NewLeague_N')
# ('Hits', 'CHmRun', 'CRuns')
# ('Hits', 'CHmRun', 'CRBI')
# ('Hits', 'CHmRun', 'CWalks')
# ('Hits', 'CHmRun', 'PutOuts')
# ('Hits', 'CHmRun', 'Assists')
# ('Hits', 'CHmRun', 'Errors')
# ('Hits', 'CHmRun', 'League_N')
# ('Hits', 'CHmRun', 'Division_W')
# ('Hits', 'CHmRun', 'NewLeague_N')
# ('Hits', 'CRuns', 'CRBI')
# ('Hits', 'CRuns', 'CWalks')
# ('Hits', 'CRuns', 'PutOuts')
# ('Hits', 'CRuns', 'Assists')
# ('Hits', 'CRuns', 'Errors')
# ('Hits', 'CRuns', 'League_N')
# ('Hits', 'CRuns', 'Division_W')
# ('Hits', 'CRuns', 'NewLeague_N')
# ('Hits', 'CRBI', 'CWalks')
# ('Hits', 'CRBI', 'PutOuts')
# ('Hits', 'CRBI', 'Assists')
# ('Hits', 'CRBI', 'Errors')
# ('Hits', 'CRBI', 'League_N')
# ('Hits', 'CRBI', 'Division_W')
# ('Hits', 'CRBI', 'NewLeague_N')
# ('Hits', 'CWalks', 'PutOuts')
# ('Hits', 'CWalks', 'Assists')
# ('Hits', 'CWalks', 'Errors')
# ('Hits', 'CWalks', 'League_N')
# ('Hits', 'CWalks', 'Division_W')
# ('Hits', 'CWalks', 'NewLeague_N')
# ('Hits', 'PutOuts', 'Assists')
# ('Hits', 'PutOuts', 'Errors')
# ('Hits', 'PutOuts', 'League_N')
# ('Hits', 'PutOuts', 'Division_W')
# ('Hits', 'PutOuts', 'NewLeague_N')
# ('Hits', 'Assists', 'Errors')
# ('Hits', 'Assists', 'League_N')
# ('Hits', 'Assists', 'Division_W')
# ('Hits', 'Assists', 'NewLeague_N')
# ('Hits', 'Errors', 'League_N')
# ('Hits', 'Errors', 'Division_W')
# ('Hits', 'Errors', 'NewLeague_N')
# ('Hits', 'League_N', 'Division_W')
# ('Hits', 'League_N', 'NewLeague_N')
# ('Hits', 'Division_W', 'NewLeague_N')
# ('HmRun', 'Runs', 'RBI')
# ('HmRun', 'Runs', 'Walks')
# ('HmRun', 'Runs', 'Years')
# ('HmRun', 'Runs', 'CAtBat')
# ('HmRun', 'Runs', 'CHits')
# ('HmRun', 'Runs', 'CHmRun')
# ('HmRun', 'Runs', 'CRuns')
# ('HmRun', 'Runs', 'CRBI')
# ('HmRun', 'Runs', 'CWalks')
# ('HmRun', 'Runs', 'PutOuts')
# ('HmRun', 'Runs', 'Assists')
# ('HmRun', 'Runs', 'Errors')
# ('HmRun', 'Runs', 'League_N')
# ('HmRun', 'Runs', 'Division_W')
# ('HmRun', 'Runs', 'NewLeague_N')
# ('HmRun', 'RBI', 'Walks')
# ('HmRun', 'RBI', 'Years')
# ('HmRun', 'RBI', 'CAtBat')
# ('HmRun', 'RBI', 'CHits')
# ('HmRun', 'RBI', 'CHmRun')
# ('HmRun', 'RBI', 'CRuns')
# ('HmRun', 'RBI', 'CRBI')
# ('HmRun', 'RBI', 'CWalks')
# ('HmRun', 'RBI', 'PutOuts')
# ('HmRun', 'RBI', 'Assists')
# ('HmRun', 'RBI', 'Errors')
# ('HmRun', 'RBI', 'League_N')
# ('HmRun', 'RBI', 'Division_W')
# ('HmRun', 'RBI', 'NewLeague_N')
# ('HmRun', 'Walks', 'Years')
# ('HmRun', 'Walks', 'CAtBat')
# ('HmRun', 'Walks', 'CHits')
# ('HmRun', 'Walks', 'CHmRun')
# ('HmRun', 'Walks', 'CRuns')
# ('HmRun', 'Walks', 'CRBI')
# ('HmRun', 'Walks', 'CWalks')
# ('HmRun', 'Walks', 'PutOuts')
# ('HmRun', 'Walks', 'Assists')
# ('HmRun', 'Walks', 'Errors')
# ('HmRun', 'Walks', 'League_N')
# ('HmRun', 'Walks', 'Division_W')
# ('HmRun', 'Walks', 'NewLeague_N')
# ('HmRun', 'Years', 'CAtBat')
# ('HmRun', 'Years', 'CHits')
# ('HmRun', 'Years', 'CHmRun')
# ('HmRun', 'Years', 'CRuns')
# ('HmRun', 'Years', 'CRBI')
# ('HmRun', 'Years', 'CWalks')
# ('HmRun', 'Years', 'PutOuts')
# ('HmRun', 'Years', 'Assists')
# ('HmRun', 'Years', 'Errors')
# ('HmRun', 'Years', 'League_N')
# ('HmRun', 'Years', 'Division_W')
# ('HmRun', 'Years', 'NewLeague_N')
# ('HmRun', 'CAtBat', 'CHits')
# ('HmRun', 'CAtBat', 'CHmRun')
# ('HmRun', 'CAtBat', 'CRuns')
# ('HmRun', 'CAtBat', 'CRBI')
# ('HmRun', 'CAtBat', 'CWalks')
# ('HmRun', 'CAtBat', 'PutOuts')
# ('HmRun', 'CAtBat', 'Assists')
# ('HmRun', 'CAtBat', 'Errors')
# ('HmRun', 'CAtBat', 'League_N')
# ('HmRun', 'CAtBat', 'Division_W')
# ('HmRun', 'CAtBat', 'NewLeague_N')
# ('HmRun', 'CHits', 'CHmRun')
# ('HmRun', 'CHits', 'CRuns')
# ('HmRun', 'CHits', 'CRBI')
# ('HmRun', 'CHits', 'CWalks')
# ('HmRun', 'CHits', 'PutOuts')
# ('HmRun', 'CHits', 'Assists')
# ('HmRun', 'CHits', 'Errors')
# ('HmRun', 'CHits', 'League_N')
# ('HmRun', 'CHits', 'Division_W')
# ('HmRun', 'CHits', 'NewLeague_N')
# ('HmRun', 'CHmRun', 'CRuns')
# ('HmRun', 'CHmRun', 'CRBI')
# ('HmRun', 'CHmRun', 'CWalks')
# ('HmRun', 'CHmRun', 'PutOuts')
# ('HmRun', 'CHmRun', 'Assists')
# ('HmRun', 'CHmRun', 'Errors')
# ('HmRun', 'CHmRun', 'League_N')
# ('HmRun', 'CHmRun', 'Division_W')
# ('HmRun', 'CHmRun', 'NewLeague_N')
# ('HmRun', 'CRuns', 'CRBI')
# ('HmRun', 'CRuns', 'CWalks')
# ('HmRun', 'CRuns', 'PutOuts')
# ('HmRun', 'CRuns', 'Assists')
# ('HmRun', 'CRuns', 'Errors')
# ('HmRun', 'CRuns', 'League_N')
# ('HmRun', 'CRuns', 'Division_W')
# ('HmRun', 'CRuns', 'NewLeague_N')
# ('HmRun', 'CRBI', 'CWalks')
# ('HmRun', 'CRBI', 'PutOuts')
# ('HmRun', 'CRBI', 'Assists')
# ('HmRun', 'CRBI', 'Errors')
# ('HmRun', 'CRBI', 'League_N')
# ('HmRun', 'CRBI', 'Division_W')
# ('HmRun', 'CRBI', 'NewLeague_N')
# ('HmRun', 'CWalks', 'PutOuts')
# ('HmRun', 'CWalks', 'Assists')
# ('HmRun', 'CWalks', 'Errors')
# ('HmRun', 'CWalks', 'League_N')
# ('HmRun', 'CWalks', 'Division_W')
# ('HmRun', 'CWalks', 'NewLeague_N')
# ('HmRun', 'PutOuts', 'Assists')
# ('HmRun', 'PutOuts', 'Errors')
# ('HmRun', 'PutOuts', 'League_N')
# ('HmRun', 'PutOuts', 'Division_W')
# ('HmRun', 'PutOuts', 'NewLeague_N')
# ('HmRun', 'Assists', 'Errors')
# ('HmRun', 'Assists', 'League_N')
# ('HmRun', 'Assists', 'Division_W')
# ('HmRun', 'Assists', 'NewLeague_N')
# ('HmRun', 'Errors', 'League_N')
# ('HmRun', 'Errors', 'Division_W')
# ('HmRun', 'Errors', 'NewLeague_N')
# ('HmRun', 'League_N', 'Division_W')
# ('HmRun', 'League_N', 'NewLeague_N')
# ('HmRun', 'Division_W', 'NewLeague_N')
# ('Runs', 'RBI', 'Walks')
# ('Runs', 'RBI', 'Years')
# ('Runs', 'RBI', 'CAtBat')
# ('Runs', 'RBI', 'CHits')
# ('Runs', 'RBI', 'CHmRun')
# ('Runs', 'RBI', 'CRuns')
# ('Runs', 'RBI', 'CRBI')
# ('Runs', 'RBI', 'CWalks')
# ('Runs', 'RBI', 'PutOuts')
# ('Runs', 'RBI', 'Assists')
# ('Runs', 'RBI', 'Errors')
# ('Runs', 'RBI', 'League_N')
# ('Runs', 'RBI', 'Division_W')
# ('Runs', 'RBI', 'NewLeague_N')
# ('Runs', 'Walks', 'Years')
# ('Runs', 'Walks', 'CAtBat')
# ('Runs', 'Walks', 'CHits')
# ('Runs', 'Walks', 'CHmRun')
# ('Runs', 'Walks', 'CRuns')
# ('Runs', 'Walks', 'CRBI')
# ('Runs', 'Walks', 'CWalks')
# ('Runs', 'Walks', 'PutOuts')
# ('Runs', 'Walks', 'Assists')
# ('Runs', 'Walks', 'Errors')
# ('Runs', 'Walks', 'League_N')
# ('Runs', 'Walks', 'Division_W')
# ('Runs', 'Walks', 'NewLeague_N')
# ('Runs', 'Years', 'CAtBat')
# ('Runs', 'Years', 'CHits')
# ('Runs', 'Years', 'CHmRun')
# ('Runs', 'Years', 'CRuns')
# ('Runs', 'Years', 'CRBI')
# ('Runs', 'Years', 'CWalks')
# ('Runs', 'Years', 'PutOuts')
# ('Runs', 'Years', 'Assists')
# ('Runs', 'Years', 'Errors')
# ('Runs', 'Years', 'League_N')
# ('Runs', 'Years', 'Division_W')
# ('Runs', 'Years', 'NewLeague_N')
# ('Runs', 'CAtBat', 'CHits')
# ('Runs', 'CAtBat', 'CHmRun')
# ('Runs', 'CAtBat', 'CRuns')
# ('Runs', 'CAtBat', 'CRBI')
# ('Runs', 'CAtBat', 'CWalks')
# ('Runs', 'CAtBat', 'PutOuts')
# ('Runs', 'CAtBat', 'Assists')
# ('Runs', 'CAtBat', 'Errors')
# ('Runs', 'CAtBat', 'League_N')
# ('Runs', 'CAtBat', 'Division_W')
# ('Runs', 'CAtBat', 'NewLeague_N')
# ('Runs', 'CHits', 'CHmRun')
# ('Runs', 'CHits', 'CRuns')
# ('Runs', 'CHits', 'CRBI')
# ('Runs', 'CHits', 'CWalks')
# ('Runs', 'CHits', 'PutOuts')
# ('Runs', 'CHits', 'Assists')
# ('Runs', 'CHits', 'Errors')
# ('Runs', 'CHits', 'League_N')
# ('Runs', 'CHits', 'Division_W')
# ('Runs', 'CHits', 'NewLeague_N')
# ('Runs', 'CHmRun', 'CRuns')
# ('Runs', 'CHmRun', 'CRBI')
# ('Runs', 'CHmRun', 'CWalks')
# ('Runs', 'CHmRun', 'PutOuts')
# ('Runs', 'CHmRun', 'Assists')
# ('Runs', 'CHmRun', 'Errors')
# ('Runs', 'CHmRun', 'League_N')
# ('Runs', 'CHmRun', 'Division_W')
# ('Runs', 'CHmRun', 'NewLeague_N')
# ('Runs', 'CRuns', 'CRBI')
# ('Runs', 'CRuns', 'CWalks')
# ('Runs', 'CRuns', 'PutOuts')
# ('Runs', 'CRuns', 'Assists')
# ('Runs', 'CRuns', 'Errors')
# ('Runs', 'CRuns', 'League_N')
# ('Runs', 'CRuns', 'Division_W')
# ('Runs', 'CRuns', 'NewLeague_N')
# ('Runs', 'CRBI', 'CWalks')
# ('Runs', 'CRBI', 'PutOuts')
# ('Runs', 'CRBI', 'Assists')
# ('Runs', 'CRBI', 'Errors')
# ('Runs', 'CRBI', 'League_N')
# ('Runs', 'CRBI', 'Division_W')
# ('Runs', 'CRBI', 'NewLeague_N')
# ('Runs', 'CWalks', 'PutOuts')
# ('Runs', 'CWalks', 'Assists')
# ('Runs', 'CWalks', 'Errors')
# ('Runs', 'CWalks', 'League_N')
# ('Runs', 'CWalks', 'Division_W')
# ('Runs', 'CWalks', 'NewLeague_N')
# ('Runs', 'PutOuts', 'Assists')
# ('Runs', 'PutOuts', 'Errors')
# ('Runs', 'PutOuts', 'League_N')
# ('Runs', 'PutOuts', 'Division_W')
# ('Runs', 'PutOuts', 'NewLeague_N')
# ('Runs', 'Assists', 'Errors')
# ('Runs', 'Assists', 'League_N')
# ('Runs', 'Assists', 'Division_W')
# ('Runs', 'Assists', 'NewLeague_N')
# ('Runs', 'Errors', 'League_N')
# ('Runs', 'Errors', 'Division_W')
# ('Runs', 'Errors', 'NewLeague_N')
# ('Runs', 'League_N', 'Division_W')
# ('Runs', 'League_N', 'NewLeague_N')
# ('Runs', 'Division_W', 'NewLeague_N')
# ('RBI', 'Walks', 'Years')
# ('RBI', 'Walks', 'CAtBat')
# ('RBI', 'Walks', 'CHits')
# ('RBI', 'Walks', 'CHmRun')
# ('RBI', 'Walks', 'CRuns')
# ('RBI', 'Walks', 'CRBI')
# ('RBI', 'Walks', 'CWalks')
# ('RBI', 'Walks', 'PutOuts')
# ('RBI', 'Walks', 'Assists')
# ('RBI', 'Walks', 'Errors')
# ('RBI', 'Walks', 'League_N')
# ('RBI', 'Walks', 'Division_W')
# ('RBI', 'Walks', 'NewLeague_N')
# ('RBI', 'Years', 'CAtBat')
# ('RBI', 'Years', 'CHits')
# ('RBI', 'Years', 'CHmRun')
# ('RBI', 'Years', 'CRuns')
# ('RBI', 'Years', 'CRBI')
# ('RBI', 'Years', 'CWalks')
# ('RBI', 'Years', 'PutOuts')
# ('RBI', 'Years', 'Assists')
# ('RBI', 'Years', 'Errors')
# ('RBI', 'Years', 'League_N')
# ('RBI', 'Years', 'Division_W')
# ('RBI', 'Years', 'NewLeague_N')
# ('RBI', 'CAtBat', 'CHits')
# ('RBI', 'CAtBat', 'CHmRun')
# ('RBI', 'CAtBat', 'CRuns')
# ('RBI', 'CAtBat', 'CRBI')
# ('RBI', 'CAtBat', 'CWalks')
# ('RBI', 'CAtBat', 'PutOuts')
# ('RBI', 'CAtBat', 'Assists')
# ('RBI', 'CAtBat', 'Errors')
# ('RBI', 'CAtBat', 'League_N')
# ('RBI', 'CAtBat', 'Division_W')
# ('RBI', 'CAtBat', 'NewLeague_N')
# ('RBI', 'CHits', 'CHmRun')
# ('RBI', 'CHits', 'CRuns')
# ('RBI', 'CHits', 'CRBI')
# ('RBI', 'CHits', 'CWalks')
# ('RBI', 'CHits', 'PutOuts')
# ('RBI', 'CHits', 'Assists')
# ('RBI', 'CHits', 'Errors')
# ('RBI', 'CHits', 'League_N')
# ('RBI', 'CHits', 'Division_W')
# ('RBI', 'CHits', 'NewLeague_N')
# ('RBI', 'CHmRun', 'CRuns')
# ('RBI', 'CHmRun', 'CRBI')
# ('RBI', 'CHmRun', 'CWalks')
# ('RBI', 'CHmRun', 'PutOuts')
# ('RBI', 'CHmRun', 'Assists')
# ('RBI', 'CHmRun', 'Errors')
# ('RBI', 'CHmRun', 'League_N')
# ('RBI', 'CHmRun', 'Division_W')
# ('RBI', 'CHmRun', 'NewLeague_N')
# ('RBI', 'CRuns', 'CRBI')
# ('RBI', 'CRuns', 'CWalks')
# ('RBI', 'CRuns', 'PutOuts')
# ('RBI', 'CRuns', 'Assists')
# ('RBI', 'CRuns', 'Errors')
# ('RBI', 'CRuns', 'League_N')
# ('RBI', 'CRuns', 'Division_W')
# ('RBI', 'CRuns', 'NewLeague_N')
# ('RBI', 'CRBI', 'CWalks')
# ('RBI', 'CRBI', 'PutOuts')
# ('RBI', 'CRBI', 'Assists')
# ('RBI', 'CRBI', 'Errors')
# ('RBI', 'CRBI', 'League_N')
# ('RBI', 'CRBI', 'Division_W')
# ('RBI', 'CRBI', 'NewLeague_N')
# ('RBI', 'CWalks', 'PutOuts')
# ('RBI', 'CWalks', 'Assists')
# ('RBI', 'CWalks', 'Errors')
# ('RBI', 'CWalks', 'League_N')
# ('RBI', 'CWalks', 'Division_W')
# ('RBI', 'CWalks', 'NewLeague_N')
# ('RBI', 'PutOuts', 'Assists')
# ('RBI', 'PutOuts', 'Errors')
# ('RBI', 'PutOuts', 'League_N')
# ('RBI', 'PutOuts', 'Division_W')
# ('RBI', 'PutOuts', 'NewLeague_N')
# ('RBI', 'Assists', 'Errors')
# ('RBI', 'Assists', 'League_N')
# ('RBI', 'Assists', 'Division_W')
# ('RBI', 'Assists', 'NewLeague_N')
# ('RBI', 'Errors', 'League_N')
# ('RBI', 'Errors', 'Division_W')
# ('RBI', 'Errors', 'NewLeague_N')
# ('RBI', 'League_N', 'Division_W')
# ('RBI', 'League_N', 'NewLeague_N')
# ('RBI', 'Division_W', 'NewLeague_N')
# ('Walks', 'Years', 'CAtBat')
# ('Walks', 'Years', 'CHits')
# ('Walks', 'Years', 'CHmRun')
# ('Walks', 'Years', 'CRuns')
# ('Walks', 'Years', 'CRBI')
# ('Walks', 'Years', 'CWalks')
# ('Walks', 'Years', 'PutOuts')
# ('Walks', 'Years', 'Assists')
# ('Walks', 'Years', 'Errors')
# ('Walks', 'Years', 'League_N')
# ('Walks', 'Years', 'Division_W')
# ('Walks', 'Years', 'NewLeague_N')
# ('Walks', 'CAtBat', 'CHits')
# ('Walks', 'CAtBat', 'CHmRun')
# ('Walks', 'CAtBat', 'CRuns')
# ('Walks', 'CAtBat', 'CRBI')
# ('Walks', 'CAtBat', 'CWalks')
# ('Walks', 'CAtBat', 'PutOuts')
# ('Walks', 'CAtBat', 'Assists')
# ('Walks', 'CAtBat', 'Errors')
# ('Walks', 'CAtBat', 'League_N')
# ('Walks', 'CAtBat', 'Division_W')
# ('Walks', 'CAtBat', 'NewLeague_N')
# ('Walks', 'CHits', 'CHmRun')
# ('Walks', 'CHits', 'CRuns')
# ('Walks', 'CHits', 'CRBI')
# ('Walks', 'CHits', 'CWalks')
# ('Walks', 'CHits', 'PutOuts')
# ('Walks', 'CHits', 'Assists')
# ('Walks', 'CHits', 'Errors')
# ('Walks', 'CHits', 'League_N')
# ('Walks', 'CHits', 'Division_W')
# ('Walks', 'CHits', 'NewLeague_N')
# ('Walks', 'CHmRun', 'CRuns')
# ('Walks', 'CHmRun', 'CRBI')
# ('Walks', 'CHmRun', 'CWalks')
# ('Walks', 'CHmRun', 'PutOuts')
# ('Walks', 'CHmRun', 'Assists')
# ('Walks', 'CHmRun', 'Errors')
# ('Walks', 'CHmRun', 'League_N')
# ('Walks', 'CHmRun', 'Division_W')
# ('Walks', 'CHmRun', 'NewLeague_N')
# ('Walks', 'CRuns', 'CRBI')
# ('Walks', 'CRuns', 'CWalks')
# ('Walks', 'CRuns', 'PutOuts')
# ('Walks', 'CRuns', 'Assists')
# ('Walks', 'CRuns', 'Errors')
# ('Walks', 'CRuns', 'League_N')
# ('Walks', 'CRuns', 'Division_W')
# ('Walks', 'CRuns', 'NewLeague_N')
# ('Walks', 'CRBI', 'CWalks')
# ('Walks', 'CRBI', 'PutOuts')
# ('Walks', 'CRBI', 'Assists')
# ('Walks', 'CRBI', 'Errors')
# ('Walks', 'CRBI', 'League_N')
# ('Walks', 'CRBI', 'Division_W')
# ('Walks', 'CRBI', 'NewLeague_N')
# ('Walks', 'CWalks', 'PutOuts')
# ('Walks', 'CWalks', 'Assists')
# ('Walks', 'CWalks', 'Errors')
# ('Walks', 'CWalks', 'League_N')
# ('Walks', 'CWalks', 'Division_W')
# ('Walks', 'CWalks', 'NewLeague_N')
# ('Walks', 'PutOuts', 'Assists')
# ('Walks', 'PutOuts', 'Errors')
# ('Walks', 'PutOuts', 'League_N')
# ('Walks', 'PutOuts', 'Division_W')
# ('Walks', 'PutOuts', 'NewLeague_N')
# ('Walks', 'Assists', 'Errors')
# ('Walks', 'Assists', 'League_N')
# ('Walks', 'Assists', 'Division_W')
# ('Walks', 'Assists', 'NewLeague_N')
# ('Walks', 'Errors', 'League_N')
# ('Walks', 'Errors', 'Division_W')
# ('Walks', 'Errors', 'NewLeague_N')
# ('Walks', 'League_N', 'Division_W')
# ('Walks', 'League_N', 'NewLeague_N')
# ('Walks', 'Division_W', 'NewLeague_N')
# ('Years', 'CAtBat', 'CHits')
# ('Years', 'CAtBat', 'CHmRun')
# ('Years', 'CAtBat', 'CRuns')
# ('Years', 'CAtBat', 'CRBI')
# ('Years', 'CAtBat', 'CWalks')
# ('Years', 'CAtBat', 'PutOuts')
# ('Years', 'CAtBat', 'Assists')
# ('Years', 'CAtBat', 'Errors')
# ('Years', 'CAtBat', 'League_N')
# ('Years', 'CAtBat', 'Division_W')
# ('Years', 'CAtBat', 'NewLeague_N')
# ('Years', 'CHits', 'CHmRun')
# ('Years', 'CHits', 'CRuns')
# ('Years', 'CHits', 'CRBI')
# ('Years', 'CHits', 'CWalks')
# ('Years', 'CHits', 'PutOuts')
# ('Years', 'CHits', 'Assists')
# ('Years', 'CHits', 'Errors')
# ('Years', 'CHits', 'League_N')
# ('Years', 'CHits', 'Division_W')
# ('Years', 'CHits', 'NewLeague_N')
# ('Years', 'CHmRun', 'CRuns')
# ('Years', 'CHmRun', 'CRBI')
# ('Years', 'CHmRun', 'CWalks')
# ('Years', 'CHmRun', 'PutOuts')
# ('Years', 'CHmRun', 'Assists')
# ('Years', 'CHmRun', 'Errors')
# ('Years', 'CHmRun', 'League_N')
# ('Years', 'CHmRun', 'Division_W')
# ('Years', 'CHmRun', 'NewLeague_N')
# ('Years', 'CRuns', 'CRBI')
# ('Years', 'CRuns', 'CWalks')
# ('Years', 'CRuns', 'PutOuts')
# ('Years', 'CRuns', 'Assists')
# ('Years', 'CRuns', 'Errors')
# ('Years', 'CRuns', 'League_N')
# ('Years', 'CRuns', 'Division_W')
# ('Years', 'CRuns', 'NewLeague_N')
# ('Years', 'CRBI', 'CWalks')
# ('Years', 'CRBI', 'PutOuts')
# ('Years', 'CRBI', 'Assists')
# ('Years', 'CRBI', 'Errors')
# ('Years', 'CRBI', 'League_N')
# ('Years', 'CRBI', 'Division_W')
# ('Years', 'CRBI', 'NewLeague_N')
# ('Years', 'CWalks', 'PutOuts')
# ('Years', 'CWalks', 'Assists')
# ('Years', 'CWalks', 'Errors')
# ('Years', 'CWalks', 'League_N')
# ('Years', 'CWalks', 'Division_W')
# ('Years', 'CWalks', 'NewLeague_N')
# ('Years', 'PutOuts', 'Assists')
# ('Years', 'PutOuts', 'Errors')
# ('Years', 'PutOuts', 'League_N')
# ('Years', 'PutOuts', 'Division_W')
# ('Years', 'PutOuts', 'NewLeague_N')
# ('Years', 'Assists', 'Errors')
# ('Years', 'Assists', 'League_N')
# ('Years', 'Assists', 'Division_W')
# ('Years', 'Assists', 'NewLeague_N')
# ('Years', 'Errors', 'League_N')
# ('Years', 'Errors', 'Division_W')
# ('Years', 'Errors', 'NewLeague_N')
# ('Years', 'League_N', 'Division_W')
# ('Years', 'League_N', 'NewLeague_N')
# ('Years', 'Division_W', 'NewLeague_N')
# ('CAtBat', 'CHits', 'CHmRun')
# ('CAtBat', 'CHits', 'CRuns')
# ('CAtBat', 'CHits', 'CRBI')
# ('CAtBat', 'CHits', 'CWalks')
# ('CAtBat', 'CHits', 'PutOuts')
# ('CAtBat', 'CHits', 'Assists')
# ('CAtBat', 'CHits', 'Errors')
# ('CAtBat', 'CHits', 'League_N')
# ('CAtBat', 'CHits', 'Division_W')
# ('CAtBat', 'CHits', 'NewLeague_N')
# ('CAtBat', 'CHmRun', 'CRuns')
# ('CAtBat', 'CHmRun', 'CRBI')
# ('CAtBat', 'CHmRun', 'CWalks')
# ('CAtBat', 'CHmRun', 'PutOuts')
# ('CAtBat', 'CHmRun', 'Assists')
# ('CAtBat', 'CHmRun', 'Errors')
# ('CAtBat', 'CHmRun', 'League_N')
# ('CAtBat', 'CHmRun', 'Division_W')
# ('CAtBat', 'CHmRun', 'NewLeague_N')
# ('CAtBat', 'CRuns', 'CRBI')
# ('CAtBat', 'CRuns', 'CWalks')
# ('CAtBat', 'CRuns', 'PutOuts')
# ('CAtBat', 'CRuns', 'Assists')
# ('CAtBat', 'CRuns', 'Errors')
# ('CAtBat', 'CRuns', 'League_N')
# ('CAtBat', 'CRuns', 'Division_W')
# ('CAtBat', 'CRuns', 'NewLeague_N')
# ('CAtBat', 'CRBI', 'CWalks')
# ('CAtBat', 'CRBI', 'PutOuts')
# ('CAtBat', 'CRBI', 'Assists')
# ('CAtBat', 'CRBI', 'Errors')
# ('CAtBat', 'CRBI', 'League_N')
# ('CAtBat', 'CRBI', 'Division_W')
# ('CAtBat', 'CRBI', 'NewLeague_N')
# ('CAtBat', 'CWalks', 'PutOuts')
# ('CAtBat', 'CWalks', 'Assists')
# ('CAtBat', 'CWalks', 'Errors')
# ('CAtBat', 'CWalks', 'League_N')
# ('CAtBat', 'CWalks', 'Division_W')
# ('CAtBat', 'CWalks', 'NewLeague_N')
# ('CAtBat', 'PutOuts', 'Assists')
# ('CAtBat', 'PutOuts', 'Errors')
# ('CAtBat', 'PutOuts', 'League_N')
# ('CAtBat', 'PutOuts', 'Division_W')
# ('CAtBat', 'PutOuts', 'NewLeague_N')
# ('CAtBat', 'Assists', 'Errors')
# ('CAtBat', 'Assists', 'League_N')
# ('CAtBat', 'Assists', 'Division_W')
# ('CAtBat', 'Assists', 'NewLeague_N')
# ('CAtBat', 'Errors', 'League_N')
# ('CAtBat', 'Errors', 'Division_W')
# ('CAtBat', 'Errors', 'NewLeague_N')
# ('CAtBat', 'League_N', 'Division_W')
# ('CAtBat', 'League_N', 'NewLeague_N')
# ('CAtBat', 'Division_W', 'NewLeague_N')
# ('CHits', 'CHmRun', 'CRuns')
# ('CHits', 'CHmRun', 'CRBI')
# ('CHits', 'CHmRun', 'CWalks')
# ('CHits', 'CHmRun', 'PutOuts')
# ('CHits', 'CHmRun', 'Assists')
# ('CHits', 'CHmRun', 'Errors')
# ('CHits', 'CHmRun', 'League_N')
# ('CHits', 'CHmRun', 'Division_W')
# ('CHits', 'CHmRun', 'NewLeague_N')
# ('CHits', 'CRuns', 'CRBI')
# ('CHits', 'CRuns', 'CWalks')
# ('CHits', 'CRuns', 'PutOuts')
# ('CHits', 'CRuns', 'Assists')
# ('CHits', 'CRuns', 'Errors')
# ('CHits', 'CRuns', 'League_N')
# ('CHits', 'CRuns', 'Division_W')
# ('CHits', 'CRuns', 'NewLeague_N')
# ('CHits', 'CRBI', 'CWalks')
# ('CHits', 'CRBI', 'PutOuts')
# ('CHits', 'CRBI', 'Assists')
# ('CHits', 'CRBI', 'Errors')
# ('CHits', 'CRBI', 'League_N')
# ('CHits', 'CRBI', 'Division_W')
# ('CHits', 'CRBI', 'NewLeague_N')
# ('CHits', 'CWalks', 'PutOuts')
# ('CHits', 'CWalks', 'Assists')
# ('CHits', 'CWalks', 'Errors')
# ('CHits', 'CWalks', 'League_N')
# ('CHits', 'CWalks', 'Division_W')
# ('CHits', 'CWalks', 'NewLeague_N')
# ('CHits', 'PutOuts', 'Assists')
# ('CHits', 'PutOuts', 'Errors')
# ('CHits', 'PutOuts', 'League_N')
# ('CHits', 'PutOuts', 'Division_W')
# ('CHits', 'PutOuts', 'NewLeague_N')
# ('CHits', 'Assists', 'Errors')
# ('CHits', 'Assists', 'League_N')
# ('CHits', 'Assists', 'Division_W')
# ('CHits', 'Assists', 'NewLeague_N')
# ('CHits', 'Errors', 'League_N')
# ('CHits', 'Errors', 'Division_W')
# ('CHits', 'Errors', 'NewLeague_N')
# ('CHits', 'League_N', 'Division_W')
# ('CHits', 'League_N', 'NewLeague_N')
# ('CHits', 'Division_W', 'NewLeague_N')
# ('CHmRun', 'CRuns', 'CRBI')
# ('CHmRun', 'CRuns', 'CWalks')
# ('CHmRun', 'CRuns', 'PutOuts')
# ('CHmRun', 'CRuns', 'Assists')
# ('CHmRun', 'CRuns', 'Errors')
# ('CHmRun', 'CRuns', 'League_N')
# ('CHmRun', 'CRuns', 'Division_W')
# ('CHmRun', 'CRuns', 'NewLeague_N')
# ('CHmRun', 'CRBI', 'CWalks')
# ('CHmRun', 'CRBI', 'PutOuts')
# ('CHmRun', 'CRBI', 'Assists')
# ('CHmRun', 'CRBI', 'Errors')
# ('CHmRun', 'CRBI', 'League_N')
# ('CHmRun', 'CRBI', 'Division_W')
# ('CHmRun', 'CRBI', 'NewLeague_N')
# ('CHmRun', 'CWalks', 'PutOuts')
# ('CHmRun', 'CWalks', 'Assists')
# ('CHmRun', 'CWalks', 'Errors')
# ('CHmRun', 'CWalks', 'League_N')
# ('CHmRun', 'CWalks', 'Division_W')
# ('CHmRun', 'CWalks', 'NewLeague_N')
# ('CHmRun', 'PutOuts', 'Assists')
# ('CHmRun', 'PutOuts', 'Errors')
# ('CHmRun', 'PutOuts', 'League_N')
# ('CHmRun', 'PutOuts', 'Division_W')
# ('CHmRun', 'PutOuts', 'NewLeague_N')
# ('CHmRun', 'Assists', 'Errors')
# ('CHmRun', 'Assists', 'League_N')
# ('CHmRun', 'Assists', 'Division_W')
# ('CHmRun', 'Assists', 'NewLeague_N')
# ('CHmRun', 'Errors', 'League_N')
# ('CHmRun', 'Errors', 'Division_W')
# ('CHmRun', 'Errors', 'NewLeague_N')
# ('CHmRun', 'League_N', 'Division_W')
# ('CHmRun', 'League_N', 'NewLeague_N')
# ('CHmRun', 'Division_W', 'NewLeague_N')
# ('CRuns', 'CRBI', 'CWalks')
# ('CRuns', 'CRBI', 'PutOuts')
# ('CRuns', 'CRBI', 'Assists')
# ('CRuns', 'CRBI', 'Errors')
# ('CRuns', 'CRBI', 'League_N')
# ('CRuns', 'CRBI', 'Division_W')
# ('CRuns', 'CRBI', 'NewLeague_N')
# ('CRuns', 'CWalks', 'PutOuts')
# ('CRuns', 'CWalks', 'Assists')
# ('CRuns', 'CWalks', 'Errors')
# ('CRuns', 'CWalks', 'League_N')
# ('CRuns', 'CWalks', 'Division_W')
# ('CRuns', 'CWalks', 'NewLeague_N')
# ('CRuns', 'PutOuts', 'Assists')
# ('CRuns', 'PutOuts', 'Errors')
# ('CRuns', 'PutOuts', 'League_N')
# ('CRuns', 'PutOuts', 'Division_W')
# ('CRuns', 'PutOuts', 'NewLeague_N')
# ('CRuns', 'Assists', 'Errors')
# ('CRuns', 'Assists', 'League_N')
# ('CRuns', 'Assists', 'Division_W')
# ('CRuns', 'Assists', 'NewLeague_N')
# ('CRuns', 'Errors', 'League_N')
# ('CRuns', 'Errors', 'Division_W')
# ('CRuns', 'Errors', 'NewLeague_N')
# ('CRuns', 'League_N', 'Division_W')
# ('CRuns', 'League_N', 'NewLeague_N')
# ('CRuns', 'Division_W', 'NewLeague_N')
# ('CRBI', 'CWalks', 'PutOuts')
# ('CRBI', 'CWalks', 'Assists')
# ('CRBI', 'CWalks', 'Errors')
# ('CRBI', 'CWalks', 'League_N')
# ('CRBI', 'CWalks', 'Division_W')
# ('CRBI', 'CWalks', 'NewLeague_N')
# ('CRBI', 'PutOuts', 'Assists')
# ('CRBI', 'PutOuts', 'Errors')
# ('CRBI', 'PutOuts', 'League_N')
# ('CRBI', 'PutOuts', 'Division_W')
# ('CRBI', 'PutOuts', 'NewLeague_N')
# ('CRBI', 'Assists', 'Errors')
# ('CRBI', 'Assists', 'League_N')
# ('CRBI', 'Assists', 'Division_W')
# ('CRBI', 'Assists', 'NewLeague_N')
# ('CRBI', 'Errors', 'League_N')
# ('CRBI', 'Errors', 'Division_W')
# ('CRBI', 'Errors', 'NewLeague_N')
# ('CRBI', 'League_N', 'Division_W')
# ('CRBI', 'League_N', 'NewLeague_N')
# ('CRBI', 'Division_W', 'NewLeague_N')
# ('CWalks', 'PutOuts', 'Assists')
# ('CWalks', 'PutOuts', 'Errors')
# ('CWalks', 'PutOuts', 'League_N')
# ('CWalks', 'PutOuts', 'Division_W')
# ('CWalks', 'PutOuts', 'NewLeague_N')
# ('CWalks', 'Assists', 'Errors')
# ('CWalks', 'Assists', 'League_N')
# ('CWalks', 'Assists', 'Division_W')
# ('CWalks', 'Assists', 'NewLeague_N')
# ('CWalks', 'Errors', 'League_N')
# ('CWalks', 'Errors', 'Division_W')
# ('CWalks', 'Errors', 'NewLeague_N')
# ('CWalks', 'League_N', 'Division_W')
# ('CWalks', 'League_N', 'NewLeague_N')
# ('CWalks', 'Division_W', 'NewLeague_N')
# ('PutOuts', 'Assists', 'Errors')
# ('PutOuts', 'Assists', 'League_N')
# ('PutOuts', 'Assists', 'Division_W')
# ('PutOuts', 'Assists', 'NewLeague_N')
# ('PutOuts', 'Errors', 'League_N')
# ('PutOuts', 'Errors', 'Division_W')
# ('PutOuts', 'Errors', 'NewLeague_N')
# ('PutOuts', 'League_N', 'Division_W')
# ('PutOuts', 'League_N', 'NewLeague_N')
# ('PutOuts', 'Division_W', 'NewLeague_N')
# ('Assists', 'Errors', 'League_N')
# ('Assists', 'Errors', 'Division_W')
# ('Assists', 'Errors', 'NewLeague_N')
# ('Assists', 'League_N', 'Division_W')
# ('Assists', 'League_N', 'NewLeague_N')
# ('Assists', 'Division_W', 'NewLeague_N')
# ('Errors', 'League_N', 'Division_W')
# ('Errors', 'League_N', 'NewLeague_N')
# ('Errors', 'Division_W', 'NewLeague_N')
# ('League_N', 'Division_W', 'NewLeague_N')
# 969

# %%
X.shape
# Out:
# (263, 19)

# %%
import
